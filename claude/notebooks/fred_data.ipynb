# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
print(sys.path)
sys.path.insert(0, "/Users/garciaj42/code/MLFinance/claude")
# Out:
# ['/Users/garciaj42/code/MLFinance/claude', '/Users/garciaj42/code/MLFinance/claude', '/Users/garciaj42/code/MLFinance/claude', '/Users/garciaj42/code/MLFinance/claude', '/Users/garciaj42/code/MLFinance/claude', '/Users/garciaj42/code/MLFinance/claude', '/Users/garciaj42/code/MLFinance/claude', '/Users/garciaj42/code/MLFinance/claude/notebooks', '/opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python39.zip', '/opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9', '/opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/lib-dynload', '', '/opt/homebrew/lib/python3.9/site-packages', '/opt/homebrew/lib/python3.9/site-packages/IPython/extensions', '/Users/garciaj42/.ipython']

# %%
import fredapi
# Initialize FRED
fred_api_key='c44011f35ea9b58dc265ab237efaa525'
fred = fredapi.Fred(api_key=fred_api_key)
lookback_days = 1 * 365

# %%
from fred_collector import create_fred_collector

# %%
fc = create_fred_collector(
    fred_api=fred,
    lookback_days=lookback_days
)

# %%
import pandas as pd

# Collect macro data
macro_data = fc.get_historical_fred_data()
# Out:
# GDP 2021-10-01    24777.038
# 2022-01-01    25215.491
# 2022-04-01    25805.791
# 2022-07-01    26272.011
# 2022-10-01    26734.277
# 2023-01-01    27164.359
# 2023-04-01    27453.815
# 2023-07-01    27967.697
# 2023-10-01    28296.967
# 2024-01-01    28624.069
# 2024-04-01    29016.714
# 2024-07-01    29374.914
# dtype: float64
# UNRATE 2021-12-01    3.9
# 2022-01-01    4.0
# 2022-02-01    3.8
# 2022-03-01    3.6
# 2022-04-01    3.7
# 2022-05-01    3.6
# 2022-06-01    3.6
# 2022-07-01    3.5
# 2022-08-01    3.6
# 2022-09-01    3.5
# 2022-10-01    3.6
# 2022-11-01    3.6
# 2022-12-01    3.5
# 2023-01-01    3.4
# 2023-02-01    3.6
# 2023-03-01    3.5
# 2023-04-01    3.4
# 2023-05-01    3.7
# 2023-06-01    3.6
# 2023-07-01    3.5
# 2023-08-01    3.8
# 2023-09-01    3.8
# 2023-10-01    3.8
# 2023-11-01    3.7
# 2023-12-01    3.7
# 2024-01-01    3.7
# 2024-02-01    3.9
# 2024-03-01    3.8
# 2024-04-01    3.9
# 2024-05-01    4.0
# 2024-06-01    4.1
# 2024-07-01    4.3
# 2024-08-01    4.2
# ...

# %%
macro_data
# Out:
#                   GDP  UNRATE  CPIAUCSL  FEDFUNDS  T10Y2Y  BAMLH0A0HYM2  \
# 2023-12-25  28624.069     3.7   309.685      5.33   -0.37          3.37
# 2023-12-26  28624.069     3.7   309.685      5.33   -0.37          3.37
# 2023-12-27  28624.069     3.7   309.685      5.33   -0.41          3.34
# 2023-12-28  28624.069     3.7   309.685      5.33   -0.42          3.32
# 2023-12-29  28624.069     3.7   309.685      5.33   -0.35          3.34
# 2023-12-31  28624.069     3.7   309.685      5.33   -0.35          3.39
# 2024-01-01  28624.069     3.7   309.685      5.33   -0.35          3.39
# 2024-01-02  28624.069     3.7   309.685      5.33   -0.38          3.54
# 2024-01-03  28624.069     3.7   309.685      5.33   -0.42          3.71
# 2024-01-04  28624.069     3.7   309.685      5.33   -0.39          3.69
# 2024-01-05  28624.069     3.7   309.685      5.33   -0.35          3.68
# 2024-01-08  28624.069     3.7   309.685      5.33   -0.35          3.63
# ...

# %%
from market_indicator_data import generate_summary_stats

generate_summary_stats(macro_data)
# Out:
#                              GDP               UNRATE             CPIAUCSL  \
# start_date   2023-12-25 00:00:00  2023-12-25 00:00:00  2023-12-25 00:00:00
# end_date     2024-12-20 00:00:00  2024-12-20 00:00:00  2024-12-20 00:00:00
# data_points                  267                  267                  267
# missing_pct                  0.0                  0.0                  0.0
# mean                  29082.5536               4.0307             313.4336
# std                     314.8348                0.182               1.9752
# min                    28624.069                  3.7              309.685
# max                    29374.914                  4.3              316.441
#
#                         FEDFUNDS               T10Y2Y         BAMLH0A0HYM2  \
# start_date   2023-12-25 00:00:00  2023-12-25 00:00:00  2023-12-25 00:00:00
# end_date     2024-12-20 00:00:00  2024-12-20 00:00:00  2024-12-20 00:00:00
# ...
