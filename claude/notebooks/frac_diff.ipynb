# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path_name = "/Users/garciaj42/code/MLFinance/claude"
import sys
print(sys.path)
sys.path.insert(0, path_name)
sys.path.insert(0, "/Users/garciaj42/code/MLFinance")
# Out:
# ['/Users/garciaj42/code/MLFinance', '/Users/garciaj42/code/MLFinance/claude', '/Users/garciaj42/code/MLFinance', '/Users/garciaj42/code/MLFinance/claude', '/Users/garciaj42/code/MLFinance/claude/notebooks', '/Users/garciaj42/code/MLFinance/claude/notebooks', '/Users/garciaj42/code/MLFinance', '/opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python39.zip', '/opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9', '/opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/lib-dynload', '', '/opt/homebrew/lib/python3.9/site-packages', '/opt/homebrew/lib/python3.9/site-packages/IPython/extensions', '/Users/garciaj42/.ipython']

# %%
from claude.feature_storage import FeatureStorage

fs = FeatureStorage(path_name + "/Data/financial_features.parquet")
features = fs.load_existing_features()[0]

# %%
features
# Out:
#                                         date_time  tick_num     open     high  \
# 1970-01-01 00:00:00.000000001 2024-01-02 00:29:00       390  4818.75  4823.50
# 1970-01-01 00:00:00.000000002 2024-01-02 04:00:00       601  4822.25  4827.75
# 1970-01-01 00:00:00.000000003 2024-01-02 07:00:00       781  4826.50  4826.50
# 1970-01-01 00:00:00.000000004 2024-01-02 10:16:00       977  4790.75  4790.75
# 1970-01-01 00:00:00.000000005 2024-01-02 13:34:00      1175  4781.00  4797.00
# ...                                           ...       ...      ...      ...
# 1970-01-01 00:00:00.000026776 2024-11-13 15:47:00    309969  6025.25  6026.50
# 1970-01-01 00:00:00.000026777 2024-11-13 15:53:00    309975  6022.00  6022.25
# 1970-01-01 00:00:00.000026779 2024-11-13 16:08:00    309990  6015.50  6018.75
# 1970-01-01 00:00:00.000026782 2024-11-13 16:32:00    310014  6020.25  6021.25
# 1970-01-01 00:00:00.000026785 2024-11-13 16:52:00    310034  6021.50  6021.50
#
#                                    low    close      volume  cum_buy_volume  \
# 1970-01-01 00:00:00.000000001  4817.25  4823.50   862792.25       530240.00
# 1970-01-01 00:00:00.000000002  4820.00  4826.50  1017715.25       535397.50
# 1970-01-01 00:00:00.000000003  4786.25  4791.50   866017.75       327126.25
# 1970-01-01 00:00:00.000000004  4774.50  4780.75   937671.50       440149.75
# 1970-01-01 00:00:00.000000005  4773.75  4787.50   947780.50       507442.25
# ...                                ...      ...         ...             ...
# 1970-01-01 00:00:00.000026776  6022.50  6022.50    48210.25        18082.00
# 1970-01-01 00:00:00.000026777  6015.25  6015.25    36117.25         6022.25
# 1970-01-01 00:00:00.000026779  6015.50  6018.75    42126.50        30093.75
# 1970-01-01 00:00:00.000026782  6019.75  6021.25    48167.25        30106.00
# 1970-01-01 00:00:00.000026785  6019.50  6019.50    36123.75            0.00
#
#                                cum_ticks  cum_dollar_value  ...         SPY  \
# 1970-01-01 00:00:00.000000001        179      4.158575e+09  ...  466.663940
# 1970-01-01 00:00:00.000000002        211      4.908531e+09  ...  466.663940
# 1970-01-01 00:00:00.000026779 2024-11-13 13:00:00+00:00
# 1970-01-01 00:00:00.000026782 2024-11-13 13:00:00+00:00
# 1970-01-01 00:00:00.000026785 2024-11-13 13:00:00+00:00
#
# [13268 rows x 39 columns]

# %%
from FinancialMachineLearning.features.fracdiff import FractionalDifferentiatedFeatures

import pandas as pd
import numpy as np
import statsmodels.api as sm

cols = ['adfStat','pVal','lags','nObs','95% conf', 'corr']
out = pd.DataFrame(columns = cols)
for d in np.linspace(0, 1, 21):
    try:
        df1 = features[['close']]
        df2 = FractionalDifferentiatedFeatures.fracDiff(df1, d = d, thres = 1e-5)
        corr = np.corrcoef(df1.loc[df2.index,'close'], df2['close'])[0,1]
        df2 = sm.tsa.stattools.adfuller(df2['close'], maxlag = 1, regression = 'c', autolag = None)
        out.loc[round(d, 2)] = list(df2[:4]) + [df2[4]['5%']] + [corr]
    except Exception as e:
        print(f'd: {round(d, 2)}, error: {e}')
        continue

# %%
# Choosing .2 because 
frac_diff_value = .2

# %%
out
# Out:
#          adfStat          pVal  lags      nObs  95% conf      corr
# 0.00    0.188837  9.716285e-01   1.0  492256.0 -2.861546  1.000000
# 0.05   -2.450590  1.279635e-01   1.0     290.0 -2.871559  0.996586
# 0.10   -2.801978  5.799182e-02   1.0     338.0 -2.870129  0.991988
# 0.15   -2.408133  1.394542e-01   1.0     486.0 -2.867505  0.811372
# 0.20   -3.902871  2.013823e-03   1.0     760.0 -2.865350  0.839959
# 0.25   -2.216347  2.003661e-01   1.0    1254.0 -2.863848  0.919372
# 0.30   -4.203273  6.505435e-04   1.0    2148.0 -2.862886  0.877315
# 0.35   -8.262582  5.036749e-13   1.0    3790.0 -2.862303  0.700094
# 0.40  -18.041855  2.656189e-30   1.0    6852.0 -2.861962  0.558633
# 0.45  -31.493023  0.000000e+00   1.0   12628.0 -2.861769  0.450654
# 0.50  -52.572636  0.000000e+00   1.0   23591.0 -2.861663  0.265884
# 0.55 -148.437305  0.000000e+00   1.0   44251.0 -2.861605  0.157810
# 0.60 -201.365698  0.000000e+00   1.0   81933.0 -2.861575  0.145172
# 0.65 -269.773976  0.000000e+00   1.0  145243.0 -2.861560  0.067069
# 0.70 -352.862408  0.000000e+00   1.0  235554.0 -2.861552  0.046247
# 0.75 -453.571137  0.000000e+00   1.0  334482.0 -2.861549  0.028760
# 0.80 -538.860156  0.000000e+00   1.0  412434.0 -2.861547  0.016573
# 0.85 -599.172760  0.000000e+00   1.0  457746.0 -2.861546  0.010439
# 0.90 -643.300506  0.000000e+00   1.0  479215.0 -2.861546  0.006703
# 0.95 -677.412397  0.000000e+00   1.0  488414.0 -2.861546  0.004697
# 1.00 -706.258779  0.000000e+00   1.0  492255.0 -2.861546  0.003561

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize = (8, 5))

color = 'tab:blue'
ax1.set_xlabel('Date')
ax1.set_ylabel('FracDiff Prices')
ax1.plot(out['adfStat'], color=color, alpha=0.75, lw=1, marker = 'x')
ax1.tick_params(axis='y')
ax1.legend(['ADF Statistics'])
ax1.axhline(0, color='gray', alpha=0.75, ls='-.', lw = 1)
ax1.grid(False)

ax2 = ax1.twinx()
color = 'tab:orange'
ax2.set_ylabel('close')
ax2.plot(out['corr'], color=color, lw=1, alpha=1, marker = '^')
ax2.legend(['Correlation'], loc='upper right')
ax2.tick_params(axis='y')

for spine in ax1.spines.values():
    spine.set_visible(False)
for spine in ax2.spines.values():
    spine.set_visible(False)
ax2.yaxis.grid(True, ls = ':', alpha = 0.5) 
plt.title('Augmented Dickey-Fuller Test & Correlation | Fractional Differentiation')

plt.show()

# %%
frac_close = FractionalDifferentiatedFeatures.fracDiff(features[['close']], frac_diff_value)

# %%
frac_close
# Out:
#                           close
# 2013-10-11 04:46:00  156.704057
# 2013-10-11 04:50:00  157.365457
# 2013-10-11 04:53:00  157.153561
# 2013-10-11 05:00:00  157.041793
# 2013-10-11 05:07:00  156.960435
# ...                         ...
# 2024-11-13 16:32:00  544.384189
# 2024-11-13 16:41:00  544.423750
# 2024-11-13 16:46:00  544.621531
# 2024-11-13 16:52:00  541.600274
# 2024-11-13 16:58:00  540.736862
#
# [364790 rows x 1 columns]

# %%
fig, ax1 = plt.subplots(figsize = (8, 5))

color = 'tab:blue'
ax1.set_xlabel('Date')
ax1.set_ylabel('FracDiff Prices')
ax1.plot(frac_close['close'], color=color, alpha=0.75, lw=1)
ax1.tick_params(axis='y')
ax1.legend(['FracDiff Prices'], loc='upper left')
ax1.set_ylim([-8.5, 21])
ax1.axhline(0, color='gray', alpha=0.75, ls='-.', lw = 1)
ax1.grid(False)

ax2 = ax1.twinx()
color = 'tab:orange'
ax2.set_ylabel('close')
ax2.plot(features['close'], color=color, lw=1, alpha=1)
ax2.tick_params(axis='y')
ax2.set_ylim([-85, 210])

for spine in ax1.spines.values():
    spine.set_visible(False)
for spine in ax2.spines.values():
    spine.set_visible(False)
ax2.yaxis.grid(True, ls = ':', alpha = 0.5) 
plt.title(f'Frac Diff Series | Expanding Window | Market : AAPL | d = {frac_diff_value}')

plt.show()

# %%
frac_close_ffd = FractionalDifferentiatedFeatures.fracDiff_FFD(features[['close']], frac_diff_value)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, ax = plt.subplots(figsize = (8, 5))

plot_pacf(
    frac_close_ffd['close'], 
    auto_ylims = True, 
    lags = range(1, 51),
    ax = ax
)
for spine in ax.spines.values():
    spine.set_visible(False)
plt.grid(False)
plt.xlabel('Time lags')
ax.yaxis.grid(True, ls = ':', alpha = 0.5) 
plt.title('Partial Auto Correlation Function')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (8, 5))

plot_acf(
    frac_close_ffd['close'], 
    auto_ylims = True, 
    lags = range(1, 51),
    ax = ax
)
for spine in ax.spines.values():
    spine.set_visible(False)
plt.grid(False)
plt.xlabel('Time lags')
ax.yaxis.grid(True, ls = ':', alpha = 0.5) 
plt.title('Auto Correlation Function')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

arima = sm.tsa.ARIMA(
    frac_close_ffd['close'], 
    order = (7,0,10), 
    trend = 'c'
).fit(method = 'innovations_mle')

# %%
print(arima.summary())

# %%
fig, ax = plt.subplots(figsize = (8, 5))
arima.resid.plot(ax = ax, lw = 0.2)
plt.title(f'ARFIMA(5, {frac_diff_value}, 10) residuals | market : {"ES"}')
plt.grid(False)
plt.axhline(0, ls = '-.', color = 'gray')
for spine in ax.spines.values():
    spine.set_visible(False)
ax.yaxis.grid(True, ls = ':', alpha = 0.5) 
plt.show()
